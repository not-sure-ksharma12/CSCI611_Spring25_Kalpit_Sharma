# %%
pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.83-py3-none-any.whl.metadata (35 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.2/922.2 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 80.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.0 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

# Load the model
model = YOLO("yolov8n.pt")

# Train the model
model.train(data="/content/drive/MyDrive/road_sign_database/dataset.yaml", epochs=20, imgsz=640, batch=16)
# Out:
# Ultralytics 8.3.83 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load the model
model = YOLO("yolov8n.pt")

# Train with higher resolution
model.train(data="/content/drive/MyDrive/road_sign_database/dataset.yaml", epochs=30, imgsz=1280, batch=8)  # Higher resolution, smaller batch
# Out:
# Ultralytics 8.3.83 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load the model
model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/road_sign_database/dataset.yaml",
    epochs=30,
    imgsz=1280,
    batch=8,
    hsv_h=0.015,  # Hue augmentation
    hsv_s=0.7,  # Saturation augmentation
    hsv_v=0.4,  # Value augmentation
    degrees=10,  # Random rotation
    translate=0.1,  # Random shift
    scale=0.5,  # Random scaling
    shear=5,  # Shear augmentation
    flipud=0.5,  # Vertical flip
    fliplr=0.5,  # Horizontal flip
)
# Out:
# Ultralytics 8.3.83 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load the trained model (best.pt)
model = YOLO("/content/drive/MyDrive/road_sign_database/M38n.pt")

# Test the model on a single image
# results = model("path_t.jpg")  # Provide the path to your image
# results.show()  # Show the results

# Test the model on a video
results = model("/content/drive/MyDrive/road_sign_database/main3.mp4", conf=0.5, save=True, stream=True, imgsz=3840)  # Process video, save output, and stream results
for r in results:
        boxes = r.boxes  # Boxes object for bbox outputs
        masks = r.masks  # Masks object for segment masks outputs
        probs = r.probs  # Class probabilities for classification outputs
# Iterate over the results generator
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (frame 415/5412) /content/drive/MyDrive/road_sign_database/main3.mp4: 2176x3840 7 cars, 2 trucks, 2 traffic lights, 76.2ms
# video 1/1 (frame 416/5412) /content/drive/MyDrive/road_sign_database/main3.mp4: 2176x3840 8 cars, 2 trucks, 2 traffic lights, 76.3ms
# video 1/1 (frame 417/5412) /content/drive/MyDrive/road_sign_database/main3.mp4: 2176x3840 6 cars, 2 trucks, 2 traffic lights, 76.4ms
# video 1/1 (frame 418/5412) /content/drive/MyDrive/road_sign_database/main3.mp4: 2176x3840 7 cars, 2 trucks, 2 traffic lights, 76.2ms
# video 1/1 (frame 419/5412) /content/drive/MyDrive/road_sign_database/main3.mp4: 2176x3840 9 cars, 2 trucks, 3 traffic lights, 76.3ms
# video 1/1 (frame 420/5412) /content/drive/MyDrive/road_sign_database/main3.mp4: 2176x3840 6 cars, 2 trucks, 2 traffic lights, 76.3ms
# video 1/1 (frame 421/5412) /content/drive/MyDrive/road_sign_database/main3.mp4: 2176x3840 5 cars, 2 trucks, 2 traffic lights, 80.1ms
# ...
